# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sdf = pd.read_excel(r"C:\Users\dougl\DA12\Capstone\capstonedata1.xlsx")

# %%
sdf.head(1)
# Out:
#            Full Name Contestant  Survivor Score  Survival Average  \
# 0  Kelly Wiglesworth      Kelly            1.34             12.26
#
#    Challenge Wins  Challenge Appearances  Challenge Win % Challenge Sit Outs  \
# 0            5.87                   16.1             0.36                  2
#
#   Votes For Bootee Votes Against The Player  ... Jury Votes % Season #  \
# 0                6                        0  ...         0.43        1
#
#   Season Title Year Aired Age         Hometown Home State  \
# 0       Borneo       2000  24  Los Angeles, CA         CA
#
#             Profession   Finish #  Gender
# 0  River Rafting Guide  Runner-Up  Female
#
# [1 rows x 26 columns]

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839 entries, 0 to 838
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Full Name                    839 non-null    object
#  1   Contestant                   839 non-null    object
#  2   Survivor Score               839 non-null    float64
#  3   Survival Average             839 non-null    float64
#  4   Challenge Wins               839 non-null    float64
#  5   Challenge Appearances        839 non-null    float64
#  6   Challenge Win %              839 non-null    float64
#  7   Challenge Sit Outs           839 non-null    object
#  8   Votes For Bootee             839 non-null    object
#  9   Votes Against The Player     839 non-null    object
#  10  Total Votes Cast             839 non-null    object
#  11  Tribal Council  Appearances  839 non-null    object
#  12  Tribal Council %             839 non-null    object
#  13  Weight Tribal Council Ratio  839 non-null    object
#  14  Jury Votes For               839 non-null    object
#  15  Total Jurors                 839 non-null    object
#  16  Jury Votes %                 839 non-null    object
#  17  Season #                     839 non-null    int64
#  18  Season Title                 839 non-null    object
#  19  Year Aired                   839 non-null    int64
#  20  Age                          839 non-null    int64
#  21  Hometown                     839 non-null    object
#  22  Home State                   839 non-null    object
#  23  Profession                   839 non-null    object
#  24  Finish #                     839 non-null    object
#  25  Gender                       839 non-null    object
# dtypes: float64(5), int64(3), object(18)
# memory usage: 170.6+ KB

# %%
cleanup = [
    'Challenge Sit Outs', 'Votes For Bootee', 'Votes Against The Player', 'Total Votes Cast',
    'Tribal Council  Appearances', 'Tribal Council %', 'Weight Tribal Council Ratio', 
    'Jury Votes For', 'Total Jurors', 'Jury Votes %'
]

# %%
for cols in cleanup:
 
    sdf[cols] = pd.to_numeric(sdf[cols], errors='coerce')

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839 entries, 0 to 838
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Full Name                    839 non-null    object
#  1   Contestant                   839 non-null    object
#  2   Survivor Score               839 non-null    float64
#  3   Survival Average             839 non-null    float64
#  4   Challenge Wins               839 non-null    float64
#  5   Challenge Appearances        839 non-null    float64
#  6   Challenge Win %              839 non-null    float64
#  7   Challenge Sit Outs           712 non-null    float64
#  8   Votes For Bootee             835 non-null    float64
#  9   Votes Against The Player     808 non-null    float64
#  10  Total Votes Cast             809 non-null    float64
#  11  Tribal Council  Appearances  809 non-null    float64
#  12  Tribal Council %             836 non-null    float64
#  13  Weight Tribal Council Ratio  836 non-null    float64
#  14  Jury Votes For               123 non-null    float64
#  15  Total Jurors                 123 non-null    float64
#  16  Jury Votes %                 123 non-null    float64
#  17  Season #                     839 non-null    int64
#  18  Season Title                 839 non-null    object
#  19  Year Aired                   839 non-null    int64
#  20  Age                          839 non-null    int64
#  21  Hometown                     839 non-null    object
#  22  Home State                   839 non-null    object
#  23  Profession                   839 non-null    object
#  24  Finish #                     839 non-null    object
#  25  Gender                       839 non-null    object
# dtypes: float64(15), int64(3), object(8)
# memory usage: 170.6+ KB

# %%
sdf = sdf.drop(columns=['Contestant'])

# %%
sdf.head(7)
# Out:
#            Full Name  Survivor Score  Survival Average  Challenge Wins  \
# 0  Kelly Wiglesworth            1.34             12.26            5.87
# 1      Richard Hatch            1.58              7.82            1.87
# 2        Rudy Boesch            1.09              3.95            1.62
# 3     Gretchen Cordy            1.12              3.85            1.23
# 4           Sue Hawk            0.95              3.67            0.87
# 5    Colleen Haskell            0.57              3.51            2.56
# 6       Sean Kenniff            0.78              3.30            1.87
#
#    Challenge Appearances  Challenge Win %  Challenge Sit Outs  \
# 0                  16.10             0.36                 2.0
# 1                  16.10             0.12                 0.0
# 2                  15.10             0.11                 3.0
# 3                   3.07             0.40                 0.0
# 4                  15.10             0.06                 0.0
# 5                  12.07             0.21                 3.0
# 6                  14.10             0.13                 0.0
#
#    Votes For Bootee  Votes Against The Player  Total Votes Cast  ...  \
# 0               6.0                       0.0              71.0  ...
# 1               9.0                       6.0              70.0  ...
# 2              10.0                       8.0              71.0  ...
# 3               3.0                       4.0              31.0  ...
# 4               9.0                       5.0              70.0  ...
# 5               3.0                       7.0              61.0  ...
# 6               6.0                       9.0              66.0  ...
#
#    Jury Votes %  Season #  Season Title  Year Aired  Age            Hometown  \
# 0          0.43         1        Borneo        2000   24     Los Angeles, CA
# 1          0.57         1        Borneo        2000   39      Providence, RI
# 2           NaN         1        Borneo        2000   72  Virginia Beach, VA
# 3           NaN         1        Borneo        2000   38     Clarksville, TN
# 4           NaN         1        Borneo        2000   38         Palmyra, WI
# 5           NaN         1        Borneo        2000   24           Miami, FL
# 6           NaN         1        Borneo        2000   30     Long Island, NY
#
#    Home State           Profession   Finish #  Gender
# 0          CA  River Rafting Guide  Runner-Up  Female
# 1          RI    Corporate Trainer     Winner    Male
# 2          VA    Retired Navy SEAL        3rd    Male
# 3          TN              Teacher       10th  Female
# 4          WI         Truck Driver        4th  Female
# 5          FL              Student        6th  Female
# 6          NY          Neurologist        5th    Male
#
# [7 rows x 25 columns]

# %%
def cleanfinish(finish):
    if 'Winner' in finish:
        return 1
    elif 'Runner-Up' in finish:
        return 2
    else:
       
        import re
        match = re.search(r'\d+', finish)
        if match:
            return int(match.group())
        return None

sdf['Finish #'] = sdf['Finish #'].apply(cleanfinish)

# %%
sdf.head(1)
# Out:
#            Full Name  Survivor Score  Survival Average  Challenge Wins  \
# 0  Kelly Wiglesworth            1.34             12.26            5.87
#
#    Challenge Appearances  Challenge Win %  Challenge Sit Outs  \
# 0                   16.1             0.36                 2.0
#
#    Votes For Bootee  Votes Against The Player  Total Votes Cast  ...  \
# 0               6.0                       0.0              71.0  ...
#
#    Jury Votes %  Season #  Season Title  Year Aired  Age         Hometown  \
# 0          0.43         1        Borneo        2000   24  Los Angeles, CA
#
#    Home State           Profession  Finish #  Gender
# 0          CA  River Rafting Guide       2.0  Female
#
# [1 rows x 25 columns]

# %%
aggregations = {
    'Survivor Score': 'mean',
    'Survival Average': 'mean',
    'Challenge Wins': 'sum',
    'Challenge Appearances': 'sum',
    'Challenge Win %': 'mean',
    'Challenge Sit Outs': 'sum',
    'Votes For Bootee': 'sum',
    'Votes Against The Player': 'sum',
    'Total Votes Cast': 'sum',
    'Tribal Council  Appearances': 'sum',
    'Tribal Council %': 'mean',
    'Weight Tribal Council Ratio': 'mean',
    'Jury Votes For': 'sum',
    'Total Jurors': 'sum',
    'Jury Votes %': 'mean',
    'Season #': 'first',
    'Season Title': 'first',
    'Year Aired': 'first',
    'Age': 'first',
    'Hometown': 'first',
    'Home State': 'first',
    'Profession': 'first',
    'Finish #': 'first',
    'Gender': 'first'
}

# %%
sdf = sdf.groupby('Full Name').agg(aggregations).reset_index()

# %%
sdf.info()
sdf.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Full Name                    705 non-null    object
#  1   Survivor Score               705 non-null    float64
#  2   Survival Average             705 non-null    float64
#  3   Challenge Wins               705 non-null    float64
#  4   Challenge Appearances        705 non-null    float64
#  5   Challenge Win %              705 non-null    float64
#  6   Challenge Sit Outs           705 non-null    float64
#  7   Votes For Bootee             705 non-null    float64
#  8   Votes Against The Player     705 non-null    float64
#  9   Total Votes Cast             705 non-null    float64
#  10  Tribal Council  Appearances  705 non-null    float64
#  11  Tribal Council %             702 non-null    float64
#  12  Weight Tribal Council Ratio  702 non-null    float64
#  13  Jury Votes For               705 non-null    float64
#  14  Total Jurors                 705 non-null    float64
#  15  Jury Votes %                 116 non-null    float64
#  16  Season #                     705 non-null    int64
#  17  Season Title                 705 non-null    object
#  18  Year Aired                   705 non-null    int64
#  19  Age                          705 non-null    int64
#  20  Hometown                     705 non-null    object
#  21  Home State                   705 non-null    object
#  22  Profession                   705 non-null    object
#  23  Finish #                     671 non-null    float64
#  24  Gender                       705 non-null    object
# dtypes: float64(16), int64(3), object(6)
# memory usage: 137.8+ KB
#           Full Name  Survivor Score  Survival Average  Challenge Wins  \
# 0    Aaron Meredith            1.18              4.42            2.65
# 1  Aaron Reisberger            0.97              2.77            0.77
#
#    Challenge Appearances  Challenge Win %  Challenge Sit Outs  \
# 0                   4.29             0.62                 0.0
# 1                   1.30             0.59                 0.0
#
#    Votes For Bootee  Votes Against The Player  Total Votes Cast  ...  \
# 0               4.0                       5.0              63.0  ...
# 1               1.0                       3.0              13.0  ...
#
#    Jury Votes %  Season #         Season Title  Year Aired  Age     Hometown  \
# 0           NaN        39  Island of the Idols        2019   36  Warwick, RI
# 1           NaN        15                China        2007   32   Venice, CA
#
#    Home State          Profession  Finish #  Gender
# 0          RI           Gym Owner       9.0    Male
# 1          CA  Surfing Instructor      11.0    Male
#
# [2 rows x 25 columns]

# %%
sdf.to_excel('cleanedcapstonev2.xlsx', index=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sdf.to_excel('cleanedcapstonev2.xlsx', index=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353     engine_kwargs=engine_kwargs,
#    2354 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\excel.py:946, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     942     need_save = False
#     943 else:
#     944     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     945     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 946     writer = ExcelWriter(  # type: ignore[abstract]
#     947         writer,
#     948         engine=engine,
#     949         storage_options=storage_options,
#     950         engine_kwargs=engine_kwargs,
#     951     )
#     952     need_save = True
#     954 try:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:61, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      57 from openpyxl.workbook import Workbook
#      59 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 61 super().__init__(
#      62     path,
#      63     mode=mode,
#      64     storage_options=storage_options,
#      65     if_sheet_exists=if_sheet_exists,
#      66     engine_kwargs=engine_kwargs,
#      67 )
#      69 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      70 # the file and later write to it
#      71 if "r+" in self._mode:  # Load from existing workbook
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1263, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1259 self._handles = IOHandles(
#    1260     cast(IO[bytes], path), compression={"compression": None}
#    1261 )
#    1262 if not isinstance(path, ExcelWriter):
# -> 1263     self._handles = get_handle(
#    1264         path, mode, storage_options=storage_options, is_text=False
#    1265     )
#    1266 self._cur_sheet = None
#    1268 if date_format is None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'cleanedcapstonev2.xlsx'

# %%
most_vap = sdf.loc['Votes Against The Player'].idxmax()
most_vap
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 most_vap = sdf.loc['Votes Against The Player'].idxmax()
#       2 most_vap
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'Votes Against The Player'
